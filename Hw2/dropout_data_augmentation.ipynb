# %%
import os
import tensorflow as tf
import keras.backend.tensorflow_backend as KTF

# assign to first GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

#VRAM memory on-demand usage(prevent Keras takes all memory at the beginning)
config = tf.ConfigProto()  
config.gpu_options.allow_growth=True   
sess = tf.Session(config=config)

KTF.set_session(sess)
# Out:
# Using TensorFlow backend.

# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D

from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import os

batch_size = 64
num_classes = 10
epochs = 200
num_predictions = 20
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_cifar10_trained_model.h5'

# The data, split between train and test sets:
(x_main, y_main), (x_test, y_test) = cifar10.load_data()

print('x shape:', x_main.shape)
x_train=x_main[:40000]
y_train=y_main[:40000]
print('x_train shape:', x_train.shape)
x_val=x_main[40000:]
y_val=y_main[40000:]
print('x_val shape:', x_val.shape)
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_val = keras.utils.to_categorical(y_val, num_classes)
# Out:
# x shape: (50000, 32, 32, 3)
# x_train shape: (40000, 32, 32, 3)
# x_val shape: (10000, 32, 32, 3)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# initiate RMSprop optimizer
opt = keras.optimizers.rmsprop(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
x_train = x_train.astype('float32')
x_val = x_val.astype('float32')
x_train /= 255
x_val /= 255

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
mc = ModelCheckpoint('best_model_dropout_data_aug.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
print('Using real-time data augmentation.')
# This will do preprocessing and realtime data augmentation:
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    zca_whitening=False,  # apply ZCA whitening
    zca_epsilon=1e-06,  # epsilon for ZCA whitening
    rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
    # randomly shift images horizontally (fraction of total width)
    width_shift_range=0.1,
    # randomly shift images vertically (fraction of total height)
    height_shift_range=0.1,
    shear_range=0.,  # set range for random shear
    zoom_range=0.,  # set range for random zoom
    channel_shift_range=0.,  # set range for random channel shifts
    # set mode for filling points outside the input boundaries
    fill_mode='nearest',
    cval=0.,  # value used for fill_mode = "constant"
    horizontal_flip=True,  # randomly flip images
    vertical_flip=False,  # randomly flip images
    # set rescaling factor (applied before any other transformation)
    rescale=None,
    # set function that will be applied on each input
    preprocessing_function=None,
    # image data format, either "channels_first" or "channels_last"
    data_format=None,
    # fraction of images reserved for validation (strictly between 0 and 1)
    validation_split=0.0)

# Compute quantities required for feature-wise normalization
# (std, mean, and principal components if ZCA whitening is applied).
datagen.fit(x_train)

# Fit the model on the batches generated by datagen.flow().
model.fit_generator(datagen.flow(x_train, y_train,
                                    batch_size=batch_size),
                    epochs=epochs,
                    validation_data=(x_val, y_val),
                    steps_per_epoch=5000,callbacks=[es, mc])
# Out:
# Using real-time data augmentation.
# Epoch 1/200
# 5000/5000 [==============================] - 165s 33ms/step - loss: 1.5378 - acc: 0.4436 - val_loss: 1.2078 - val_acc: 0.5733
#
# Epoch 00001: val_acc improved from -inf to 0.57330, saving model to best_model_dropout_data_aug.h5
# Epoch 2/200
# 5000/5000 [==============================] - 205s 41ms/step - loss: 1.1907 - acc: 0.5769 - val_loss: 1.0485 - val_acc: 0.6320
#
# Epoch 00002: val_acc improved from 0.57330 to 0.63200, saving model to best_model_dropout_data_aug.h5
# Epoch 3/200
# 5000/5000 [==============================] - 206s 41ms/step - loss: 1.0356 - acc: 0.6353 - val_loss: 0.9203 - val_acc: 0.6783
#
# Epoch 00003: val_acc improved from 0.63200 to 0.67830, saving model to best_model_dropout_data_aug.h5
# Epoch 4/200
# 5000/5000 [==============================] - 205s 41ms/step - loss: 0.9348 - acc: 0.6722 - val_loss: 0.7836 - val_acc: 0.7234
#
# Epoch 00004: val_acc improved from 0.67830 to 0.72340, saving model to best_model_dropout_data_aug.h5
# Epoch 5/200
# 5000/5000 [==============================] - 206s 41ms/step - loss: 0.8637 - acc: 0.6990 - val_loss: 0.7339 - val_acc: 0.7467
#
# Epoch 00005: val_acc improved from 0.72340 to 0.74670, saving model to best_model_dropout_data_aug.h5
# Epoch 6/200
# 5000/5000 [==============================] - 198s 40ms/step - loss: 0.8169 - acc: 0.7158 - val_loss: 0.6912 - val_acc: 0.7611
#
# Epoch 00006: val_acc improved from 0.74670 to 0.76110, saving model to best_model_dropout_data_aug.h5
# Epoch 7/200
# 5000/5000 [==============================] - 192s 38ms/step - loss: 0.7885 - acc: 0.7283 - val_loss: 0.7169 - val_acc: 0.7515
#
# Epoch 00007: val_acc did not improve from 0.76110
# Epoch 8/200
# 5000/5000 [==============================] - 193s 39ms/step - loss: 0.7668 - acc: 0.7360 - val_loss: 0.6684 - val_acc: 0.7731
#
# Epoch 00008: val_acc improved from 0.76110 to 0.77310, saving model to best_model_dropout_data_aug.h5
# Epoch 9/200
# 5000/5000 [==============================] - 195s 39ms/step - loss: 0.7505 - acc: 0.7425 - val_loss: 0.6628 - val_acc: 0.7780
#
# Epoch 00009: val_acc improved from 0.77310 to 0.77800, saving model to best_model_dropout_data_aug.h5
# Epoch 10/200
# 5000/5000 [==============================] - 170s 34ms/step - loss: 0.7362 - acc: 0.7479 - val_loss: 0.6532 - val_acc: 0.7802
#
# Epoch 00010: val_acc improved from 0.77800 to 0.78020, saving model to best_model_dropout_data_aug.h5
# Epoch 11/200
# 5000/5000 [==============================] - 107s 21ms/step - loss: 0.7270 - acc: 0.7520 - val_loss: 0.6461 - val_acc: 0.7820
#
# Epoch 00011: val_acc improved from 0.78020 to 0.78200, saving model to best_model_dropout_data_aug.h5
# Epoch 12/200
# 5000/5000 [==============================] - 106s 21ms/step - loss: 0.7171 - acc: 0.7558 - val_loss: 0.6284 - val_acc: 0.7883
#
# Epoch 00012: val_acc improved from 0.78200 to 0.78830, saving model to best_model_dropout_data_aug.h5
# Epoch 13/200
# 5000/5000 [==============================] - 105s 21ms/step - loss: 0.7088 - acc: 0.7593 - val_loss: 0.6084 - val_acc: 0.7945
#
# Epoch 00013: val_acc improved from 0.78830 to 0.79450, saving model to best_model_dropout_data_aug.h5
# Epoch 14/200
# 5000/5000 [==============================] - 105s 21ms/step - loss: 0.7001 - acc: 0.7630 - val_loss: 0.5666 - val_acc: 0.8102
#
# Epoch 00014: val_acc improved from 0.79450 to 0.81020, saving model to best_model_dropout_data_aug.h5
# Epoch 15/200
# 5000/5000 [==============================] - 106s 21ms/step - loss: 0.6948 - acc: 0.7652 - val_loss: 0.6185 - val_acc: 0.7920
#
# Epoch 00015: val_acc did not improve from 0.81020
# Epoch 16/200
# 5000/5000 [==============================] - 105s 21ms/step - loss: 0.6876 - acc: 0.7677 - val_loss: 0.5891 - val_acc: 0.7999
#
# Epoch 00016: val_acc did not improve from 0.81020
# Epoch 17/200
# 5000/5000 [==============================] - 105s 21ms/step - loss: 0.6825 - acc: 0.7705 - val_loss: 0.6327 - val_acc: 0.7881
#
# Epoch 00017: val_acc did not improve from 0.81020
# Epoch 18/200
# 5000/5000 [==============================] - 106s 21ms/step - loss: 0.6775 - acc: 0.7724 - val_loss: 0.5755 - val_acc: 0.8074
#
# Epoch 00018: val_acc did not improve from 0.81020
# Epoch 19/200
# 5000/5000 [==============================] - 105s 21ms/step - loss: 0.6730 - acc: 0.7737 - val_loss: 0.6176 - val_acc: 0.8009
#
# Epoch 00019: val_acc did not improve from 0.81020
# Epoch 20/200
# 5000/5000 [==============================] - 106s 21ms/step - loss: 0.6688 - acc: 0.7756 - val_loss: 0.5610 - val_acc: 0.8096
#
# Epoch 00020: val_acc did not improve from 0.81020
# Epoch 21/200
# 5000/5000 [==============================] - 105s 21ms/step - loss: 0.6679 - acc: 0.7759 - val_loss: 0.5824 - val_acc: 0.8087
#
# Epoch 00021: val_acc did not improve from 0.81020
# Epoch 22/200
# 5000/5000 [==============================] - 105s 21ms/step - loss: 0.6650 - acc: 0.7770 - val_loss: 0.6133 - val_acc: 0.7981
#
# Epoch 00022: val_acc did not improve from 0.81020
# Epoch 23/200
# 5000/5000 [==============================] - 105s 21ms/step - loss: 0.6640 - acc: 0.7771 - val_loss: 0.6129 - val_acc: 0.7976
#
# Epoch 00023: val_acc did not improve from 0.81020
# Epoch 24/200
# 5000/5000 [==============================] - 105s 21ms/step - loss: 0.6605 - acc: 0.7795 - val_loss: 0.5765 - val_acc: 0.8125
#
# Epoch 00024: val_acc improved from 0.81020 to 0.81250, saving model to best_model_dropout_data_aug.h5
# Epoch 25/200
# 5000/5000 [==============================] - 105s 21ms/step - loss: 0.6591 - acc: 0.7790 - val_loss: 0.6077 - val_acc: 0.7985
#
# Epoch 00025: val_acc did not improve from 0.81250
# Epoch 26/200
# 5000/5000 [==============================] - 104s 21ms/step - loss: 0.6598 - acc: 0.7796 - val_loss: 0.5818 - val_acc: 0.8105
#
# Epoch 00026: val_acc did not improve from 0.81250
# Epoch 27/200
# 5000/5000 [==============================] - 105s 21ms/step - loss: 0.6604 - acc: 0.7794 - val_loss: 0.5723 - val_acc: 0.8075
#
# Epoch 00027: val_acc did not improve from 0.81250
# Epoch 28/200
# 5000/5000 [==============================] - 105s 21ms/step - loss: 0.6579 - acc: 0.7802 - val_loss: 0.6416 - val_acc: 0.7859
#
# Epoch 00028: val_acc did not improve from 0.81250
# Epoch 29/200
# 5000/5000 [==============================] - 105s 21ms/step - loss: 0.6590 - acc: 0.7792 - val_loss: 0.6169 - val_acc: 0.7981
#
# Epoch 00029: val_acc did not improve from 0.81250
# Epoch 30/200
# 5000/5000 [==============================] - 104s 21ms/step - loss: 0.6592 - acc: 0.7804 - val_loss: 0.6290 - val_acc: 0.7961
#
# Epoch 00030: val_acc did not improve from 0.81250
# Epoch 31/200
# 5000/5000 [==============================] - 107s 21ms/step - loss: 0.6584 - acc: 0.7805 - val_loss: 0.6180 - val_acc: 0.8006
#
# Epoch 00031: val_acc did not improve from 0.81250
# Epoch 32/200
# 5000/5000 [==============================] - 106s 21ms/step - loss: 0.6578 - acc: 0.7795 - val_loss: 0.5696 - val_acc: 0.8121
#
# Epoch 00032: val_acc did not improve from 0.81250
# Epoch 33/200
# 5000/5000 [==============================] - 106s 21ms/step - loss: 0.6614 - acc: 0.7800 - val_loss: 0.6125 - val_acc: 0.7964
#
# Epoch 00033: val_acc did not improve from 0.81250
# Epoch 34/200
# 5000/5000 [==============================] - 105s 21ms/step - loss: 0.6607 - acc: 0.7802 - val_loss: 0.6632 - val_acc: 0.7904
#
# Epoch 00034: val_acc did not improve from 0.81250
# Epoch 35/200
# 5000/5000 [==============================] - 106s 21ms/step - loss: 0.6595 - acc: 0.7806 - val_loss: 0.5905 - val_acc: 0.8052
# Epoch 67/200
# 5000/5000 [==============================] - 190s 38ms/step - loss: 0.8172 - acc: 0.7366 - val_loss: 0.7032 - val_acc: 0.7810
#
# Epoch 00067: val_acc did not improve from 0.81280
# Epoch 68/200
# 5000/5000 [==============================] - 202s 40ms/step - loss: 0.8278 - acc: 0.7341 - val_loss: 0.7266 - val_acc: 0.7612
#
# Epoch 00068: val_acc did not improve from 0.81280
# Epoch 69/200
# 5000/5000 [==============================] - 200s 40ms/step - loss: 0.8430 - acc: 0.7287 - val_loss: 0.7908 - val_acc: 0.7376
#
# Epoch 00069: val_acc did not improve from 0.81280
# Epoch 70/200
# 5000/5000 [==============================] - 148s 30ms/step - loss: 0.8523 - acc: 0.7259 - val_loss: 0.7817 - val_acc: 0.7429
#
# Epoch 00070: val_acc did not improve from 0.81280
# Epoch 71/200
# 5000/5000 [==============================] - 118s 24ms/step - loss: 0.8631 - acc: 0.7234 - val_loss: 0.7980 - val_acc: 0.7266
#
# Epoch 00071: val_acc did not improve from 0.81280
# Epoch 72/200
# 5000/5000 [==============================] - 108s 22ms/step - loss: 0.8757 - acc: 0.7191 - val_loss: 0.9825 - val_acc: 0.6673
#
# Epoch 00072: val_acc did not improve from 0.81280
# Epoch 73/200
# 5000/5000 [==============================] - 110s 22ms/step - loss: 0.8843 - acc: 0.7169 - val_loss: 0.8838 - val_acc: 0.7008
#
# Epoch 00073: val_acc did not improve from 0.81280
# Epoch 74/200
# 5000/5000 [==============================] - 109s 22ms/step - loss: 0.8960 - acc: 0.7128 - val_loss: 0.7688 - val_acc: 0.7386
#
# Epoch 00074: val_acc did not improve from 0.81280
# Epoch 75/200
# 5000/5000 [==============================] - 173s 35ms/step - loss: 0.9045 - acc: 0.7108 - val_loss: 0.8654 - val_acc: 0.7186
#
# Epoch 00075: val_acc did not improve from 0.81280
# Epoch 76/200
# 5000/5000 [==============================] - 184s 37ms/step - loss: 0.9132 - acc: 0.7074 - val_loss: 0.9561 - val_acc: 0.7058
#
# Epoch 00076: val_acc did not improve from 0.81280
# Epoch 77/200
# 5000/5000 [==============================] - 177s 35ms/step - loss: 0.9205 - acc: 0.7070 - val_loss: 1.0380 - val_acc: 0.6205
#
# Epoch 00077: val_acc did not improve from 0.81280
# Epoch 78/200
# 5000/5000 [==============================] - 186s 37ms/step - loss: 0.9255 - acc: 0.7044 - val_loss: 0.7762 - val_acc: 0.7586
#
# Epoch 00078: val_acc did not improve from 0.81280
# Epoch 79/200
# 5000/5000 [==============================] - 123s 25ms/step - loss: 0.9382 - acc: 0.7003 - val_loss: 0.9206 - val_acc: 0.6970
#
# Epoch 00079: val_acc did not improve from 0.81280
# Epoch 80/200
# 5000/5000 [==============================] - 178s 36ms/step - loss: 0.9428 - acc: 0.6987 - val_loss: 0.7226 - val_acc: 0.7736
#
# Epoch 00080: val_acc did not improve from 0.81280
# Epoch 81/200
# 5000/5000 [==============================] - 197s 39ms/step - loss: 0.9509 - acc: 0.6965 - val_loss: 0.8853 - val_acc: 0.7140
#
# Epoch 00081: val_acc did not improve from 0.81280
# Epoch 82/200
# 5000/5000 [==============================] - 149s 30ms/step - loss: 0.9590 - acc: 0.6935 - val_loss: 0.8451 - val_acc: 0.7263
#
# Epoch 00082: val_acc did not improve from 0.81280
# Epoch 83/200
# 5000/5000 [==============================] - 106s 21ms/step - loss: 0.9663 - acc: 0.6907 - val_loss: 0.8335 - val_acc: 0.7529
#
# Epoch 00083: val_acc did not improve from 0.81280
# Epoch 84/200
# 5000/5000 [==============================] - 109s 22ms/step - loss: 0.9813 - acc: 0.6876 - val_loss: 0.9556 - val_acc: 0.6737
#
# Epoch 00084: val_acc did not improve from 0.81280
# Epoch 85/200
# 5000/5000 [==============================] - 110s 22ms/step - loss: 0.9929 - acc: 0.6830 - val_loss: 0.9562 - val_acc: 0.7001
#
# Epoch 00085: val_acc did not improve from 0.81280
# Epoch 86/200
# 5000/5000 [==============================] - 108s 22ms/step - loss: 1.0117 - acc: 0.6779 - val_loss: 1.2050 - val_acc: 0.6156
#
# Epoch 00086: val_acc did not improve from 0.81280
# Epoch 87/200
# 5000/5000 [==============================] - 109s 22ms/step - loss: 1.0225 - acc: 0.6743 - val_loss: 1.0026 - val_acc: 0.6688
#
# Epoch 00087: val_acc did not improve from 0.81280
# Epoch 88/200
# 5000/5000 [==============================] - 107s 21ms/step - loss: 1.0337 - acc: 0.6704 - val_loss: 1.0852 - val_acc: 0.6550
#
# Epoch 00088: val_acc did not improve from 0.81280
# Epoch 89/200
# 5000/5000 [==============================] - 106s 21ms/step - loss: 1.0466 - acc: 0.6658 - val_loss: 0.9272 - val_acc: 0.7017
#
# Epoch 00089: val_acc did not improve from 0.81280
# Epoch 90/200
# 5000/5000 [==============================] - 106s 21ms/step - loss: 1.0563 - acc: 0.6621 - val_loss: 0.8652 - val_acc: 0.7213
#
# Epoch 00090: val_acc did not improve from 0.81280
# Epoch 91/200
# 5000/5000 [==============================] - 106s 21ms/step - loss: 1.0627 - acc: 0.6601 - val_loss: 0.9209 - val_acc: 0.6809
#
# Epoch 00091: val_acc did not improve from 0.81280
# Epoch 92/200
# 1242/5000 [======>.......................] - ETA: 1:20 - loss: 1.0753 - acc: 0.6578
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-3ba04b65142b> in <module>
#      40                     epochs=epochs,
#      41                     validation_data=(x_val, y_val),
# ---> 42                     steps_per_epoch=5000,callbacks=[es, mc])
#
# E:\Anaconda3\envs\tf37\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# E:\Anaconda3\envs\tf37\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# E:\Anaconda3\envs\tf37\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     179             batch_index = 0
#     180             while steps_done < steps_per_epoch:
# --> 181                 generator_output = next(output_generator)
#     182
#     183                 if not hasattr(generator_output, '__len__'):
#
# E:\Anaconda3\envs\tf37\lib\site-packages\keras\utils\data_utils.py in get(self)
#     683         try:
#     684             while self.is_running():
# --> 685                 inputs = self.queue.get(block=True).get()
#     686                 self.queue.task_done()
#     687                 if inputs is not None:
#
# E:\Anaconda3\envs\tf37\lib\multiprocessing\pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# E:\Anaconda3\envs\tf37\lib\multiprocessing\pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# E:\Anaconda3\envs\tf37\lib\threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# E:\Anaconda3\envs\tf37\lib\threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
x_test = x_test.astype('float32')
x_test /= 255
y_test = keras.utils.to_categorical(y_test, num_classes)
model.evaluate(x=x_test, y=y_test, batch_size=batch_size, verbose=1)

# %%
# first test _val_acc=79.44%, test_acc=73.97
# second test, remove early stopping,step_per_epoch=1000->5000, epoch 300->400,batch_size 32->64

# %%
del model

# %%
from keras.models import load_model
model= load_model('best_model_dropout_data_aug.h5')

# %%
x_test = x_test.astype('float32')
x_test /= 255
y_test = keras.utils.to_categorical(y_test, num_classes)
model.evaluate(x=x_test, y=y_test, batch_size=batch_size, verbose=1)
# Out:
# 10000/10000 [==============================] - 0s 47us/step
# [0.5895635107517242, 0.8093]
