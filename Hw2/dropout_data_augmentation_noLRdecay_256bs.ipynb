# %%
import os
import tensorflow as tf
import keras.backend.tensorflow_backend as KTF

# assign to first GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

#VRAM memory on-demand usage(prevent Keras takes all memory at the beginning)
config = tf.ConfigProto()  
config.gpu_options.allow_growth=True   
sess = tf.Session(config=config)

KTF.set_session(sess)
# Out:
# Using TensorFlow backend.

# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D

from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import os

batch_size = 64
num_classes = 10
epochs = 200
num_predictions = 20
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_cifar10_trained_model.h5'

# The data, split between train and test sets:
(x_main, y_main), (x_test, y_test) = cifar10.load_data()

print('x shape:', x_main.shape)
x_train=x_main[:40000]
y_train=y_main[:40000]
print('x_train shape:', x_train.shape)
x_val=x_main[40000:]
y_val=y_main[40000:]
print('x_val shape:', x_val.shape)
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_val = keras.utils.to_categorical(y_val, num_classes)
# Out:
# x shape: (50000, 32, 32, 3)
# x_train shape: (40000, 32, 32, 3)
# x_val shape: (10000, 32, 32, 3)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# initiate RMSprop optimizer
opt = keras.optimizers.rmsprop(lr=0.0001)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
x_train = x_train.astype('float32')
x_val = x_val.astype('float32')
x_train /= 255
x_val /= 255

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=100)
mc = ModelCheckpoint('best_model_2xLR.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
print('Using real-time data augmentation.')
# This will do preprocessing and realtime data augmentation:
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    zca_whitening=False,  # apply ZCA whitening
    zca_epsilon=1e-06,  # epsilon for ZCA whitening
    rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
    # randomly shift images horizontally (fraction of total width)
    width_shift_range=0.1,
    # randomly shift images vertically (fraction of total height)
    height_shift_range=0.1,
    shear_range=0.,  # set range for random shear
    zoom_range=0.,  # set range for random zoom
    channel_shift_range=0.,  # set range for random channel shifts
    # set mode for filling points outside the input boundaries
    fill_mode='nearest',
    cval=0.,  # value used for fill_mode = "constant"
    horizontal_flip=True,  # randomly flip images
    vertical_flip=False,  # randomly flip images
    # set rescaling factor (applied before any other transformation)
    rescale=None,
    # set function that will be applied on each input
    preprocessing_function=None,
    # image data format, either "channels_first" or "channels_last"
    data_format=None,
    # fraction of images reserved for validation (strictly between 0 and 1)
    validation_split=0.0)

# Compute quantities required for feature-wise normalization
# (std, mean, and principal components if ZCA whitening is applied).
datagen.fit(x_train)

# Fit the model on the batches generated by datagen.flow().
model.fit_generator(datagen.flow(x_train, y_train,
                                    batch_size=batch_size),
                    epochs=epochs,
                    validation_data=(x_val, y_val),
                    steps_per_epoch=5000,callbacks=[es,mc])
# Out:
# Using real-time data augmentation.
# Epoch 1/200
# 5000/5000 [==============================] - 109s 22ms/step - loss: 1.5520 - acc: 0.4366 - val_loss: 1.2193 - val_acc: 0.5690
#
# Epoch 00001: val_acc improved from -inf to 0.56900, saving model to best_model_2xLR.h5
# Epoch 2/200
# 5000/5000 [==============================] - 163s 33ms/step - loss: 1.2060 - acc: 0.5719 - val_loss: 0.9936 - val_acc: 0.6490
#
# Epoch 00002: val_acc improved from 0.56900 to 0.64900, saving model to best_model_2xLR.h5
# Epoch 3/200
# 5000/5000 [==============================] - 194s 39ms/step - loss: 1.0489 - acc: 0.6309 - val_loss: 0.8579 - val_acc: 0.6996
#
# Epoch 00003: val_acc improved from 0.64900 to 0.69960, saving model to best_model_2xLR.h5
# Epoch 4/200
# 5000/5000 [==============================] - 195s 39ms/step - loss: 0.9510 - acc: 0.6661 - val_loss: 0.7970 - val_acc: 0.7227
#
# Epoch 00004: val_acc improved from 0.69960 to 0.72270, saving model to best_model_2xLR.h5
# Epoch 5/200
# 5000/5000 [==============================] - 192s 38ms/step - loss: 0.8797 - acc: 0.6937 - val_loss: 0.7532 - val_acc: 0.7381
#
# Epoch 00005: val_acc improved from 0.72270 to 0.73810, saving model to best_model_2xLR.h5
# Epoch 6/200
# 5000/5000 [==============================] - 195s 39ms/step - loss: 0.8372 - acc: 0.7100 - val_loss: 0.7031 - val_acc: 0.7580
#
# Epoch 00006: val_acc improved from 0.73810 to 0.75800, saving model to best_model_2xLR.h5
# Epoch 7/200
# 5000/5000 [==============================] - 194s 39ms/step - loss: 0.8079 - acc: 0.7219 - val_loss: 0.7227 - val_acc: 0.7514
#
# Epoch 00007: val_acc did not improve from 0.75800
# Epoch 8/200
# 5000/5000 [==============================] - 180s 36ms/step - loss: 0.7859 - acc: 0.7303 - val_loss: 0.6613 - val_acc: 0.7788
#
# Epoch 00008: val_acc improved from 0.75800 to 0.77880, saving model to best_model_2xLR.h5
# Epoch 9/200
# 5000/5000 [==============================] - 186s 37ms/step - loss: 0.7647 - acc: 0.7393 - val_loss: 0.6749 - val_acc: 0.7657
#
# Epoch 00009: val_acc did not improve from 0.77880
# Epoch 10/200
# 5000/5000 [==============================] - 185s 37ms/step - loss: 0.7507 - acc: 0.7439 - val_loss: 0.6246 - val_acc: 0.7854
#
# Epoch 00010: val_acc improved from 0.77880 to 0.78540, saving model to best_model_2xLR.h5
# Epoch 11/200
# 5000/5000 [==============================] - 188s 38ms/step - loss: 0.7387 - acc: 0.7503 - val_loss: 0.6363 - val_acc: 0.7896
#
# Epoch 00011: val_acc improved from 0.78540 to 0.78960, saving model to best_model_2xLR.h5
# Epoch 12/200
# 5000/5000 [==============================] - 113s 23ms/step - loss: 0.7261 - acc: 0.7544 - val_loss: 0.5963 - val_acc: 0.8002
#
# Epoch 00012: val_acc improved from 0.78960 to 0.80020, saving model to best_model_2xLR.h5
# Epoch 13/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.7149 - acc: 0.7584 - val_loss: 0.6653 - val_acc: 0.7836
#
# Epoch 00013: val_acc did not improve from 0.80020
# Epoch 14/200
# 5000/5000 [==============================] - 103s 21ms/step - loss: 0.7066 - acc: 0.7621 - val_loss: 0.6260 - val_acc: 0.7867
#
# Epoch 00014: val_acc did not improve from 0.80020
# Epoch 15/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.6987 - acc: 0.7645 - val_loss: 0.5970 - val_acc: 0.8007
#
# Epoch 00015: val_acc improved from 0.80020 to 0.80070, saving model to best_model_2xLR.h5
# Epoch 16/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.6909 - acc: 0.7667 - val_loss: 0.6163 - val_acc: 0.7936
#
# Epoch 00016: val_acc did not improve from 0.80070
# Epoch 17/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.6864 - acc: 0.7692 - val_loss: 0.6433 - val_acc: 0.7856
#
# Epoch 00017: val_acc did not improve from 0.80070
# Epoch 18/200
# 5000/5000 [==============================] - 103s 21ms/step - loss: 0.6833 - acc: 0.7703 - val_loss: 0.6175 - val_acc: 0.7911
#
# Epoch 00018: val_acc did not improve from 0.80070
# Epoch 19/200
# 5000/5000 [==============================] - 103s 21ms/step - loss: 0.6795 - acc: 0.7726 - val_loss: 0.6604 - val_acc: 0.7814
#
# Epoch 00019: val_acc did not improve from 0.80070
# Epoch 20/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.6768 - acc: 0.7731 - val_loss: 0.6350 - val_acc: 0.7905
#
# Epoch 00020: val_acc did not improve from 0.80070
# Epoch 21/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.6772 - acc: 0.7735 - val_loss: 0.6284 - val_acc: 0.7878
#
# Epoch 00021: val_acc did not improve from 0.80070
# Epoch 22/200
# 5000/5000 [==============================] - 104s 21ms/step - loss: 0.6736 - acc: 0.7746 - val_loss: 0.5799 - val_acc: 0.8045
#
# Epoch 00022: val_acc improved from 0.80070 to 0.80450, saving model to best_model_2xLR.h5
# Epoch 23/200
# 5000/5000 [==============================] - 101s 20ms/step - loss: 0.6718 - acc: 0.7753 - val_loss: 0.6582 - val_acc: 0.7800
#
# Epoch 00023: val_acc did not improve from 0.80450
# Epoch 24/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.6733 - acc: 0.7757 - val_loss: 0.5766 - val_acc: 0.8124
#
# Epoch 00024: val_acc improved from 0.80450 to 0.81240, saving model to best_model_2xLR.h5
# Epoch 25/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.6715 - acc: 0.7757 - val_loss: 0.5917 - val_acc: 0.8024
#
# Epoch 00025: val_acc did not improve from 0.81240
# Epoch 26/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.6692 - acc: 0.7764 - val_loss: 0.6141 - val_acc: 0.7896
#
# Epoch 00026: val_acc did not improve from 0.81240
# Epoch 27/200
# 5000/5000 [==============================] - 101s 20ms/step - loss: 0.6703 - acc: 0.7771 - val_loss: 0.6429 - val_acc: 0.7781
#
# Epoch 00027: val_acc did not improve from 0.81240
# Epoch 28/200
# 5000/5000 [==============================] - 101s 20ms/step - loss: 0.6721 - acc: 0.7770 - val_loss: 0.5632 - val_acc: 0.8123
#
# Epoch 00028: val_acc did not improve from 0.81240
# Epoch 29/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.6751 - acc: 0.7761 - val_loss: 0.6370 - val_acc: 0.7951
#
# Epoch 00029: val_acc did not improve from 0.81240
# Epoch 30/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.6730 - acc: 0.7761 - val_loss: 0.6089 - val_acc: 0.8005
#
# Epoch 00030: val_acc did not improve from 0.81240
# Epoch 31/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.6753 - acc: 0.7762 - val_loss: 0.6357 - val_acc: 0.7884
#
# Epoch 00031: val_acc did not improve from 0.81240
# Epoch 32/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.6753 - acc: 0.7766 - val_loss: 0.6209 - val_acc: 0.8003
#
# Epoch 00032: val_acc did not improve from 0.81240
# Epoch 33/200
# 5000/5000 [==============================] - 103s 21ms/step - loss: 0.6747 - acc: 0.7758 - val_loss: 0.5665 - val_acc: 0.8122
#
# Epoch 00033: val_acc did not improve from 0.81240
# Epoch 34/200
# 5000/5000 [==============================] - 103s 21ms/step - loss: 0.6785 - acc: 0.7758 - val_loss: 0.6497 - val_acc: 0.7851
#
# Epoch 00034: val_acc did not improve from 0.81240
# Epoch 35/200
# 5000/5000 [==============================] - 103s 21ms/step - loss: 0.6801 - acc: 0.7754 - val_loss: 0.6360 - val_acc: 0.7896
#
# Epoch 00035: val_acc did not improve from 0.81240
# Epoch 36/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.6833 - acc: 0.7739 - val_loss: 0.6042 - val_acc: 0.8094
#
# Epoch 00036: val_acc did not improve from 0.81240
# Epoch 37/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.6832 - acc: 0.7747 - val_loss: 0.6221 - val_acc: 0.7901
#
# Epoch 00037: val_acc did not improve from 0.81240
# Epoch 38/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.6877 - acc: 0.7725 - val_loss: 0.5870 - val_acc: 0.8069
#
# Epoch 00038: val_acc did not improve from 0.81240
# Epoch 39/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.6903 - acc: 0.7731 - val_loss: 0.6073 - val_acc: 0.8075
#
# Epoch 00039: val_acc did not improve from 0.81240
# Epoch 40/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.6934 - acc: 0.7723 - val_loss: 0.6364 - val_acc: 0.7903
#
# Epoch 00040: val_acc did not improve from 0.81240
# Epoch 41/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.6997 - acc: 0.7710 - val_loss: 0.6063 - val_acc: 0.8013
#
# Epoch 00041: val_acc did not improve from 0.81240
# Epoch 42/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.7001 - acc: 0.7695 - val_loss: 0.7344 - val_acc: 0.7574
#
# Epoch 00042: val_acc did not improve from 0.81240
# Epoch 43/200
# 5000/5000 [==============================] - 103s 21ms/step - loss: 0.7072 - acc: 0.7695 - val_loss: 0.7249 - val_acc: 0.7568
#
# Epoch 00043: val_acc did not improve from 0.81240
# Epoch 44/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.7063 - acc: 0.7692 - val_loss: 0.5910 - val_acc: 0.8007
#
# Epoch 00044: val_acc did not improve from 0.81240
# Epoch 45/200
# 5000/5000 [==============================] - 103s 21ms/step - loss: 0.7136 - acc: 0.7666 - val_loss: 0.6305 - val_acc: 0.7960
#
# Epoch 00045: val_acc did not improve from 0.81240
# Epoch 46/200
# 5000/5000 [==============================] - 103s 21ms/step - loss: 0.7169 - acc: 0.7659 - val_loss: 0.6723 - val_acc: 0.7760
#
# Epoch 00046: val_acc did not improve from 0.81240
# Epoch 47/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.7231 - acc: 0.7646 - val_loss: 0.6662 - val_acc: 0.7828
#
# Epoch 00047: val_acc did not improve from 0.81240
# Epoch 48/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.7244 - acc: 0.7636 - val_loss: 0.6751 - val_acc: 0.7735
#
# Epoch 00048: val_acc did not improve from 0.81240
# Epoch 49/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.7285 - acc: 0.7632 - val_loss: 0.6458 - val_acc: 0.7884
#
# Epoch 00049: val_acc did not improve from 0.81240
# Epoch 50/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.7380 - acc: 0.7601 - val_loss: 0.6874 - val_acc: 0.7741
#
# Epoch 00050: val_acc did not improve from 0.81240
# Epoch 51/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.7460 - acc: 0.7580 - val_loss: 0.6467 - val_acc: 0.7862
#
# Epoch 00051: val_acc did not improve from 0.81240
# Epoch 52/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.7473 - acc: 0.7570 - val_loss: 0.7246 - val_acc: 0.7620
#
# Epoch 00052: val_acc did not improve from 0.81240
# Epoch 53/200
# 5000/5000 [==============================] - 101s 20ms/step - loss: 0.7535 - acc: 0.7559 - val_loss: 0.7003 - val_acc: 0.7858
#
# Epoch 00053: val_acc did not improve from 0.81240
# Epoch 54/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.7603 - acc: 0.7538 - val_loss: 0.6668 - val_acc: 0.7769
#
# Epoch 00054: val_acc did not improve from 0.81240
# Epoch 55/200
# 5000/5000 [==============================] - 102s 20ms/step - loss: 0.7679 - acc: 0.7522 - val_loss: 0.7803 - val_acc: 0.7591
#
# Epoch 00055: val_acc did not improve from 0.81240
# Epoch 56/200
# 5000/5000 [==============================] - 104s 21ms/step - loss: 0.7709 - acc: 0.7502 - val_loss: 0.6669 - val_acc: 0.7918
#
# Epoch 00056: val_acc did not improve from 0.81240
# Epoch 57/200
# 5000/5000 [==============================] - 104s 21ms/step - loss: 0.7775 - acc: 0.7484 - val_loss: 0.6678 - val_acc: 0.7919
#
# Epoch 00057: val_acc did not improve from 0.81240
# Epoch 58/200
# 5000/5000 [==============================] - 104s 21ms/step - loss: 0.7885 - acc: 0.7458 - val_loss: 0.6722 - val_acc: 0.7834
#
# Epoch 00058: val_acc did not improve from 0.81240
# Epoch 59/200
# 5000/5000 [==============================] - 106s 21ms/step - loss: 0.7981 - acc: 0.7436 - val_loss: 0.6941 - val_acc: 0.7724
#
# Epoch 00059: val_acc did not improve from 0.81240
# Epoch 60/200
# 5000/5000 [==============================] - 127s 25ms/step - loss: 0.8033 - acc: 0.7410 - val_loss: 0.7135 - val_acc: 0.7702
#
# Epoch 00060: val_acc did not improve from 0.81240
# Epoch 61/200
# 5000/5000 [==============================] - 187s 37ms/step - loss: 0.8143 - acc: 0.7381 - val_loss: 0.8618 - val_acc: 0.7043
#
# Epoch 00061: val_acc did not improve from 0.81240
# Epoch 62/200
# 5000/5000 [==============================] - 198s 40ms/step - loss: 0.8216 - acc: 0.7364 - val_loss: 0.6564 - val_acc: 0.7848
#
# Epoch 00062: val_acc did not improve from 0.81240
# Epoch 63/200
# 5000/5000 [==============================] - 193s 39ms/step - loss: 0.8313 - acc: 0.7331 - val_loss: 0.7776 - val_acc: 0.7436
#
# Epoch 00063: val_acc did not improve from 0.81240
# Epoch 64/200
# 5000/5000 [==============================] - 186s 37ms/step - loss: 0.8389 - acc: 0.7310 - val_loss: 0.7533 - val_acc: 0.7647
#
# Epoch 00064: val_acc did not improve from 0.81240
# Epoch 65/200
# 5000/5000 [==============================] - 196s 39ms/step - loss: 0.8495 - acc: 0.7273 - val_loss: 0.6872 - val_acc: 0.7716
#
# Epoch 00065: val_acc did not improve from 0.81240
# Epoch 66/200
# 5000/5000 [==============================] - 198s 40ms/step - loss: 0.8634 - acc: 0.7222 - val_loss: 0.6742 - val_acc: 0.7785
#
# Epoch 00066: val_acc did not improve from 0.81240
# Epoch 67/200
# 5000/5000 [==============================] - 195s 39ms/step - loss: 0.8746 - acc: 0.7202 - val_loss: 0.7899 - val_acc: 0.7263
#
# Epoch 00067: val_acc did not improve from 0.81240
# Epoch 68/200
# 5000/5000 [==============================] - 193s 39ms/step - loss: 0.8894 - acc: 0.7153 - val_loss: 0.9107 - val_acc: 0.7120
#
# Epoch 00068: val_acc did not improve from 0.81240
# Epoch 69/200
# 5000/5000 [==============================] - 187s 37ms/step - loss: 0.9070 - acc: 0.7112 - val_loss: 0.8645 - val_acc: 0.7134
#
# Epoch 00069: val_acc did not improve from 0.81240
# Epoch 70/200
# 5000/5000 [==============================] - 180s 36ms/step - loss: 0.9221 - acc: 0.7053 - val_loss: 0.8009 - val_acc: 0.7368
#
# Epoch 00070: val_acc did not improve from 0.81240
# Epoch 71/200
# 5000/5000 [==============================] - 184s 37ms/step - loss: 0.9399 - acc: 0.7008 - val_loss: 0.8288 - val_acc: 0.7325
#
# Epoch 00071: val_acc did not improve from 0.81240
# Epoch 72/200
# 5000/5000 [==============================] - 190s 38ms/step - loss: 0.9566 - acc: 0.6963 - val_loss: 0.8800 - val_acc: 0.7081
#
# Epoch 00072: val_acc did not improve from 0.81240
# Epoch 73/200
# 5000/5000 [==============================] - 184s 37ms/step - loss: 0.9782 - acc: 0.6889 - val_loss: 0.7766 - val_acc: 0.7353
#
# Epoch 00073: val_acc did not improve from 0.81240
# Epoch 74/200
# 5000/5000 [==============================] - 112s 22ms/step - loss: 0.9891 - acc: 0.6863 - val_loss: 1.0781 - val_acc: 0.6802
#
# Epoch 00074: val_acc did not improve from 0.81240
# Epoch 75/200
# 5000/5000 [==============================] - 115s 23ms/step - loss: 0.9975 - acc: 0.6831 - val_loss: 0.7481 - val_acc: 0.7573
#
# Epoch 00075: val_acc did not improve from 0.81240
# Epoch 76/200
# 5000/5000 [==============================] - 107s 21ms/step - loss: 1.0085 - acc: 0.6791 - val_loss: 0.8899 - val_acc: 0.6994
#
# Epoch 00076: val_acc did not improve from 0.81240
# Epoch 77/200
# 5000/5000 [==============================] - 106s 21ms/step - loss: 1.0220 - acc: 0.6749 - val_loss: 0.8667 - val_acc: 0.7231
#
# Epoch 00077: val_acc did not improve from 0.81240
# Epoch 78/200
# 5000/5000 [==============================] - 111s 22ms/step - loss: 1.0331 - acc: 0.6721 - val_loss: 0.8453 - val_acc: 0.7270
#
# Epoch 00078: val_acc did not improve from 0.81240
# Epoch 79/200
# 5000/5000 [==============================] - 180s 36ms/step - loss: 1.0356 - acc: 0.6711 - val_loss: 0.9645 - val_acc: 0.7009
#
# Epoch 00079: val_acc did not improve from 0.81240
# Epoch 80/200
# 5000/5000 [==============================] - 175s 35ms/step - loss: 1.0434 - acc: 0.6689 - val_loss: 1.0054 - val_acc: 0.6537
#
# Epoch 00080: val_acc did not improve from 0.81240
# Epoch 81/200
# 5000/5000 [==============================] - 172s 34ms/step - loss: 1.0547 - acc: 0.6647 - val_loss: 0.8883 - val_acc: 0.6947
#
# Epoch 00081: val_acc did not improve from 0.81240
# Epoch 82/200
# 5000/5000 [==============================] - 170s 34ms/step - loss: 1.0739 - acc: 0.6591 - val_loss: 0.9484 - val_acc: 0.6757
#
# Epoch 00082: val_acc did not improve from 0.81240
# Epoch 83/200
# 5000/5000 [==============================] - 126s 25ms/step - loss: 1.0889 - acc: 0.6529 - val_loss: 0.9822 - val_acc: 0.6891
#
# Epoch 00083: val_acc did not improve from 0.81240
# Epoch 84/200
# 5000/5000 [==============================] - 171s 34ms/step - loss: 1.0987 - acc: 0.6504 - val_loss: 0.8857 - val_acc: 0.7025
#
# Epoch 00084: val_acc did not improve from 0.81240
# Epoch 85/200
# 5000/5000 [==============================] - 187s 37ms/step - loss: 1.1176 - acc: 0.6461 - val_loss: 1.0751 - val_acc: 0.6653
#
# Epoch 00085: val_acc did not improve from 0.81240
# Epoch 86/200
# 5000/5000 [==============================] - 144s 29ms/step - loss: 1.1210 - acc: 0.6436 - val_loss: 0.8650 - val_acc: 0.7130
#
# Epoch 00086: val_acc did not improve from 0.81240
# Epoch 87/200
# 5000/5000 [==============================] - 103s 21ms/step - loss: 1.1290 - acc: 0.6402 - val_loss: 0.9591 - val_acc: 0.6810
#
# Epoch 00087: val_acc did not improve from 0.81240
# Epoch 88/200
# 5000/5000 [==============================] - 106s 21ms/step - loss: 1.1347 - acc: 0.6385 - val_loss: 1.0049 - val_acc: 0.6535
#
# Epoch 00088: val_acc did not improve from 0.81240
# Epoch 89/200
# 5000/5000 [==============================] - 107s 21ms/step - loss: 1.1362 - acc: 0.6380 - val_loss: 1.1276 - val_acc: 0.6343
#
# Epoch 00089: val_acc did not improve from 0.81240
# Epoch 90/200
# 5000/5000 [==============================] - 106s 21ms/step - loss: 1.1414 - acc: 0.6376 - val_loss: 0.9326 - val_acc: 0.6865
#
# Epoch 00090: val_acc did not improve from 0.81240
# Epoch 91/200
# 5000/5000 [==============================] - 106s 21ms/step - loss: 1.1539 - acc: 0.6321 - val_loss: 1.0447 - val_acc: 0.6636
#
# Epoch 00091: val_acc did not improve from 0.81240
# Epoch 92/200
# 5000/5000 [==============================] - 104s 21ms/step - loss: 1.1628 - acc: 0.6291 - val_loss: 1.0323 - val_acc: 0.6423
#
# Epoch 00092: val_acc did not improve from 0.81240
# Epoch 93/200
# 5000/5000 [==============================] - 103s 21ms/step - loss: 1.1644 - acc: 0.6296 - val_loss: 1.1001 - val_acc: 0.6530
#
# Epoch 00093: val_acc did not improve from 0.81240
# Epoch 94/200
# 5000/5000 [==============================] - 103s 21ms/step - loss: 1.1523 - acc: 0.6317 - val_loss: 0.9662 - val_acc: 0.6734
#
# Epoch 00094: val_acc did not improve from 0.81240
# Epoch 95/200
# 5000/5000 [==============================] - 103s 21ms/step - loss: 1.1438 - acc: 0.6341 - val_loss: 0.9345 - val_acc: 0.6783
#
# Epoch 00095: val_acc did not improve from 0.81240
# Epoch 96/200
# 2726/5000 [===============>..............] - ETA: 47s - loss: 1.1342 - acc: 0.6364
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-ed97b8141f17> in <module>
#      40                     epochs=epochs,
#      41                     validation_data=(x_val, y_val),
# ---> 42                     steps_per_epoch=5000,callbacks=[es,mc])
#
# E:\Anaconda3\envs\tf37\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# E:\Anaconda3\envs\tf37\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# E:\Anaconda3\envs\tf37\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     179             batch_index = 0
#     180             while steps_done < steps_per_epoch:
# --> 181                 generator_output = next(output_generator)
#     182
#     183                 if not hasattr(generator_output, '__len__'):
#
# E:\Anaconda3\envs\tf37\lib\site-packages\keras\utils\data_utils.py in get(self)
#     683         try:
#     684             while self.is_running():
# --> 685                 inputs = self.queue.get(block=True).get()
#     686                 self.queue.task_done()
#     687                 if inputs is not None:
#
# E:\Anaconda3\envs\tf37\lib\multiprocessing\pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# E:\Anaconda3\envs\tf37\lib\multiprocessing\pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# E:\Anaconda3\envs\tf37\lib\threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# E:\Anaconda3\envs\tf37\lib\threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
x_test = x_test.astype('float32')
x_test /= 255
y_test = keras.utils.to_categorical(y_test, num_classes)
model.evaluate(x=x_test, y=y_test, batch_size=batch_size, verbose=1)
# Out:
# 10000/10000 [==============================] - 0s 44us/step
# [0.9591198930740357, 0.6793]

# %%
del model

# %%
from keras.models import load_model
model= load_model('best_model_2xLR.h5')

# %%
model.evaluate(x=x_test, y=y_test, batch_size=batch_size, verbose=1)
# Out:
# 10000/10000 [==============================] - 0s 49us/step
# [0.5958372214794159, 0.8054]
